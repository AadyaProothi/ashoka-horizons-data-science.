# %% [markdown]
# <a href="https://colab.research.google.com/github/AadyaProothi/AadyaProothi/blob/main/final_ashoka_horizons_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas
#!pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly

# %%
import pandas as pd


df = pd.read_csv('records.csv')

# Display the first 5 rows
print(df.head())

# Display the last 5 rows
print(df.tail())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0            NaN      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    float64
#  1   Glucose                   765 non-null    float64
#  2   BloodPressure             765 non-null    float64
#  3   SkinThickness             766 non-null    float64
#  4   Insulin                   765 non-null    float64
#  5   BMI                       766 non-null    float64
#  6   DiabetesPedigreeFunction  766 non-null    float64
#  7   Age                       767 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
sns.scatterplot(x='Glucose', y='Outcome', data=df)
plt.title('Glucose vs Outcome')
plt.xlabel('Glucose')
plt.ylabel('Outcome')
plt.show()

# %%
df = pd.read_csv('records.csv')

# %%
df = df.dropna()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.histplot(df['Glucose'], kde=True)
plt.title('Distribution of Glucose')

plt.subplot(2, 2, 2)
sns.histplot(df['BMI'], kde=True)
plt.title('Distribution of BMI')

plt.subplot(2, 2, 3)
sns.histplot(df['Age'], kde=True)
plt.title('Distribution of Age')

plt.subplot(2, 2, 4)
sns.histplot(df['Pregnancies'], kde=True)
plt.title('Distribution of Pregnancies')

plt.tight_layout()
plt.show()

sns.scatterplot(x='Glucose', y='Outcome', data=df)
plt.title('Glucose vs Outcome')
plt.xlabel('Glucose')
plt.ylabel('Outcome')
plt.show()
